# %%
# 1. Imports & Setup (Same as before)
# -------------------------------------------------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from transformers import AutoModel, AutoTokenizer
from tqdm import tqdm
import os

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.manual_seed(42)

# %%
TRAIN_PATH = "/content/ptbrtrain.csv"
VAL_PATH   = "/content/ptbrval.csv"
TEST_PATH  = "/content/ptbrtest.csv"


train_df = pd.read_csv(TRAIN_PATH)
val_df   = pd.read_csv(VAL_PATH)
test_df  = pd.read_csv(TEST_PATH)

# %%
train_df.head()
# Out:
#                          id  \
# 0  ptbr_train_track_a_00001
# 1  ptbr_train_track_a_00002
# 2  ptbr_train_track_a_00003
# 3  ptbr_train_track_a_00004
# 4  ptbr_train_track_a_00005
#
#                                                 text  anger  disgust  fear  \
# 0  Moça eu fiz uma análise com o Tinder uma vez e...      0        0     0
# 1  eles sempre mostram a míseria, em como tudo er...      1        1     0
# 2  eu nunca quis tanto algo como quero você. jama...      0        0     0
# 3  esperando aqui o stf vim me emparedar do eu ex...      1        0     0
# 4  e no final o PS vai pagar o pato, ja é o 4° tr...      1        0     0
#
#    joy  sadness  surprise
# 0    0        0         0
# 1    0        0         0
# 2    1        1         0
# 3    0        0         0
# 4    0        0         0

# %%
# Instead of a single LABEL_VAR, define multiple label columns:
LABEL_COLS = ["anger", "disgust", "fear", "joy", "sadness", "surprise"]
TEXT_VAR   = "text"

# %%
# 3. Load Tokenizer & Model for Embedding Extraction
# -------------------------------------------------------
model_name = "Hate-speech-CNERG/dehatebert-mono-portugese"
text_tokenizer = AutoTokenizer.from_pretrained(model_name)
text_model = AutoModel.from_pretrained(model_name).to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/152 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.23k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/669M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]

# %%
# Collect the counts of "1" for each label
counts_ones = []
for label in LABEL_COLS:
    # Count how many rows in train_df have this label = 1
    num_ones = (train_df[label] == 1).sum()
    counts_ones.append((label, num_ones))

# Build a DataFrame for plotting
counts_df = pd.DataFrame(counts_ones, columns=["label", "count_of_1"])

plt.figure(figsize=(8, 6))
sns.barplot(
    x="label",
    y="count_of_1",
    data=counts_df,
    palette="Set2"
)
plt.title("Counts of 1 for Each Label")
plt.xlabel("Label")
plt.ylabel("Count of 1")
plt.tight_layout()
plt.show()

# %%
# 4. Extract Text Embeddings (Same logic, but shorten max_length if needed)
# -------------------------------------------------------
def extract_text_embeddings(df, save_path, model, tokenizer):
    if os.path.exists(save_path):
        print(f"Embeddings already exist at {save_path}")
        return torch.load(save_path)

    embeddings = {}
    model.eval()
    with torch.no_grad():
        for idx, row in tqdm(df.iterrows(), desc="Extracting text embeddings", total=len(df)):
            text_sample = row[TEXT_VAR]
            text_sample = text_sample if isinstance(text_sample, str) else ""

            inputs = tokenizer(
                text_sample,
                padding="max_length",
                truncation=True,
                max_length=128,
                return_tensors="pt"
            ).to(device)

            outputs = model(**inputs)
            cls_embedding = outputs.last_hidden_state[:, 0, :]
            embeddings[idx] = cls_embedding.cpu()

    torch.save(embeddings, save_path)
    return embeddings

train_text_embeddings = extract_text_embeddings(train_df, "train_text_embeddings.pt", text_model, text_tokenizer)
val_text_embeddings   = extract_text_embeddings(val_df,   "val_text_embeddings.pt",   text_model, text_tokenizer)
test_text_embeddings  = extract_text_embeddings(test_df,  "test_text_embeddings.pt",  text_model, text_tokenizer)
# Out:
# Extracting text embeddings:   0%|          | 0/2226 [00:00<?, ?it/s]
# Extracting text embeddings:   0%|          | 1/2226 [00:00<30:58,  1.20it/s]
# Extracting text embeddings:   0%|          | 4/2226 [00:00<07:10,  5.16it/s]
# Extracting text embeddings:   0%|          | 7/2226 [00:01<04:03,  9.10it/s]
# Extracting text embeddings:   1%|          | 13/2226 [00:01<02:01, 18.16it/s]
# Extracting text embeddings:   1%|          | 19/2226 [00:01<01:24, 26.06it/s]
# Extracting text embeddings:   1%|          | 23/2226 [00:01<01:16, 28.94it/s]
# Extracting text embeddings:   1%|          | 27/2226 [00:01<01:13, 30.08it/s]
# Extracting text embeddings:   1%|▏         | 32/2226 [00:01<01:07, 32.66it/s]
# Extracting text embeddings:   2%|▏         | 36/2226 [00:01<01:06, 32.98it/s]
# Extracting text embeddings:   2%|▏         | 41/2226 [00:01<01:00, 35.97it/s]
# Extracting text embeddings:   2%|▏         | 46/2226 [00:02<00:58, 37.20it/s]
# Extracting text embeddings:   2%|▏         | 51/2226 [00:02<00:57, 37.85it/s]
# Extracting text embeddings:   2%|▏         | 55/2226 [00:02<01:00, 35.85it/s]
# Extracting text embeddings:   3%|▎         | 59/2226 [00:02<01:05, 33.33it/s]
# Extracting text embeddings:   3%|▎         | 63/2226 [00:02<01:03, 34.22it/s]
# Extracting text embeddings:   3%|▎         | 67/2226 [00:02<01:02, 34.28it/s]
# Extracting text embeddings:   3%|▎         | 72/2226 [00:02<01:01, 35.12it/s]
# Extracting text embeddings:   4%|▎         | 78/2226 [00:02<00:52, 40.83it/s]
# Extracting text embeddings:   4%|▍         | 87/2226 [00:03<00:41, 51.69it/s]
# Extracting text embeddings:   4%|▍         | 94/2226 [00:03<00:37, 56.15it/s]
# Extracting text embeddings:   5%|▍         | 101/2226 [00:03<00:36, 58.43it/s]
# Extracting text embeddings:   5%|▍         | 107/2226 [00:03<00:36, 58.50it/s]
# Extracting text embeddings:   5%|▌         | 115/2226 [00:03<00:33, 62.22it/s]
# Extracting text embeddings:   6%|▌         | 123/2226 [00:03<00:31, 66.76it/s]
# Extracting text embeddings:   6%|▌         | 130/2226 [00:03<00:32, 64.46it/s]
# Extracting text embeddings:   6%|▌         | 137/2226 [00:03<00:32, 64.05it/s]
# Extracting text embeddings:   7%|▋         | 145/2226 [00:03<00:31, 66.81it/s]
# Extracting text embeddings:   7%|▋         | 156/2226 [00:03<00:26, 78.53it/s]
# Extracting text embeddings:   8%|▊         | 167/2226 [00:04<00:23, 87.33it/s]
# Extracting text embeddings:   8%|▊         | 177/2226 [00:04<00:23, 88.28it/s]
# Extracting text embeddings:   8%|▊         | 188/2226 [00:04<00:22, 92.49it/s]
# Extracting text embeddings:   9%|▉         | 199/2226 [00:04<00:20, 97.36it/s]
# Extracting text embeddings:   9%|▉         | 210/2226 [00:04<00:19, 100.86it/s]
# Extracting text embeddings:  10%|▉         | 221/2226 [00:04<00:19, 103.41it/s]
# Extracting text embeddings:  10%|█         | 232/2226 [00:04<00:18, 105.10it/s]
# Extracting text embeddings:  11%|█         | 243/2226 [00:04<00:18, 106.31it/s]
# Extracting text embeddings:  11%|█▏        | 254/2226 [00:04<00:21, 90.43it/s]
# Extracting text embeddings:  12%|█▏        | 264/2226 [00:05<00:27, 70.85it/s]
# Extracting text embeddings:  12%|█▏        | 273/2226 [00:05<00:30, 64.91it/s]
# Extracting text embeddings:  13%|█▎        | 281/2226 [00:05<00:30, 64.60it/s]
# Extracting text embeddings:  13%|█▎        | 290/2226 [00:05<00:28, 68.87it/s]
# Extracting text embeddings:  13%|█▎        | 298/2226 [00:05<00:29, 65.92it/s]
# Extracting text embeddings:  14%|█▎        | 306/2226 [00:05<00:28, 68.21it/s]
# Extracting text embeddings:  14%|█▍        | 314/2226 [00:05<00:27, 69.97it/s]
# Extracting text embeddings:  15%|█▍        | 323/2226 [00:06<00:26, 71.86it/s]
# Extracting text embeddings:  15%|█▍        | 331/2226 [00:06<00:27, 69.50it/s]
# Extracting text embeddings:  15%|█▌        | 340/2226 [00:06<00:26, 71.69it/s]
# Extracting text embeddings:  16%|█▌        | 349/2226 [00:06<00:24, 76.10it/s]
# Extracting text embeddings:  16%|█▌        | 357/2226 [00:06<00:24, 75.65it/s]
# Extracting text embeddings:  16%|█▋        | 365/2226 [00:06<00:24, 74.83it/s]
# Extracting text embeddings:  17%|█▋        | 373/2226 [00:06<00:25, 71.37it/s]
# Extracting text embeddings:  17%|█▋        | 381/2226 [00:06<00:26, 70.43it/s]
# Extracting text embeddings:  17%|█▋        | 389/2226 [00:06<00:25, 70.73it/s]
# Extracting text embeddings:  18%|█▊        | 398/2226 [00:07<00:24, 75.75it/s]
# Extracting text embeddings:  18%|█▊        | 406/2226 [00:07<00:24, 75.25it/s]
# Extracting text embeddings:  19%|█▊        | 414/2226 [00:07<00:23, 75.76it/s]
# Extracting text embeddings:  19%|█▉        | 422/2226 [00:07<00:26, 68.83it/s]
# Extracting text embeddings:  19%|█▉        | 430/2226 [00:07<00:27, 64.28it/s]
# Extracting text embeddings:  20%|█▉        | 438/2226 [00:07<00:26, 67.27it/s]
# Extracting text embeddings:  20%|█▉        | 445/2226 [00:07<00:26, 67.96it/s]
# Extracting text embeddings:  20%|██        | 456/2226 [00:07<00:22, 77.62it/s]
# Extracting text embeddings:  21%|██        | 467/2226 [00:07<00:20, 84.65it/s]
# Extracting text embeddings:  21%|██▏       | 478/2226 [00:08<00:19, 91.43it/s]
# Extracting text embeddings:  22%|██▏       | 488/2226 [00:08<00:18, 93.08it/s]
# Extracting text embeddings:  22%|██▏       | 498/2226 [00:08<00:18, 92.17it/s]
# Extracting text embeddings:  23%|██▎       | 510/2226 [00:08<00:17, 97.70it/s]
# Extracting text embeddings:  23%|██▎       | 522/2226 [00:08<00:16, 101.63it/s]
# Extracting text embeddings:  24%|██▍       | 534/2226 [00:08<00:16, 104.30it/s]
# Extracting text embeddings:  24%|██▍       | 545/2226 [00:08<00:15, 105.32it/s]
# Extracting text embeddings:  25%|██▌       | 557/2226 [00:08<00:15, 106.86it/s]
# Extracting text embeddings:  26%|██▌       | 568/2226 [00:08<00:15, 105.72it/s]
# Extracting text embeddings:  26%|██▌       | 579/2226 [00:09<00:15, 106.05it/s]
# Extracting text embeddings:  27%|██▋       | 590/2226 [00:09<00:15, 106.11it/s]
# Extracting text embeddings:  27%|██▋       | 601/2226 [00:09<00:15, 102.83it/s]
# Extracting text embeddings:  27%|██▋       | 612/2226 [00:09<00:15, 103.22it/s]
# Extracting text embeddings:  28%|██▊       | 624/2226 [00:09<00:15, 105.61it/s]
# Extracting text embeddings:  29%|██▊       | 635/2226 [00:09<00:14, 106.11it/s]
# Extracting text embeddings:  29%|██▉       | 646/2226 [00:09<00:14, 106.68it/s]
# Extracting text embeddings:  30%|██▉       | 657/2226 [00:09<00:14, 104.79it/s]
# Extracting text embeddings:  30%|███       | 668/2226 [00:09<00:14, 105.97it/s]
# Extracting text embeddings:  31%|███       | 679/2226 [00:10<00:15, 102.27it/s]
# Extracting text embeddings:  31%|███       | 691/2226 [00:10<00:14, 104.68it/s]
# Extracting text embeddings:  32%|███▏      | 702/2226 [00:10<00:14, 104.56it/s]
# Extracting text embeddings:  32%|███▏      | 713/2226 [00:10<00:14, 106.02it/s]
# Extracting text embeddings:  33%|███▎      | 725/2226 [00:10<00:13, 107.31it/s]
# Extracting text embeddings:  33%|███▎      | 736/2226 [00:10<00:13, 108.05it/s]
# Extracting text embeddings:  34%|███▎      | 748/2226 [00:10<00:13, 108.85it/s]
# Extracting text embeddings:  34%|███▍      | 759/2226 [00:10<00:13, 108.80it/s]
# Extracting text embeddings:  35%|███▍      | 770/2226 [00:10<00:13, 107.45it/s]
# Extracting text embeddings:  35%|███▌      | 781/2226 [00:10<00:13, 107.30it/s]
# Extracting text embeddings:  36%|███▌      | 792/2226 [00:11<00:13, 105.09it/s]
# Extracting text embeddings:  36%|███▌      | 803/2226 [00:11<00:13, 103.73it/s]
# Extracting text embeddings:  37%|███▋      | 814/2226 [00:11<00:14, 98.07it/s]
# Extracting text embeddings:  37%|███▋      | 825/2226 [00:11<00:13, 100.81it/s]
# Extracting text embeddings:  38%|███▊      | 836/2226 [00:11<00:13, 103.26it/s]
# Extracting text embeddings:  38%|███▊      | 847/2226 [00:11<00:13, 104.73it/s]
# Extracting text embeddings:  39%|███▊      | 858/2226 [00:11<00:12, 105.63it/s]
# Extracting text embeddings:  39%|███▉      | 869/2226 [00:11<00:12, 106.76it/s]
# Extracting text embeddings:  40%|███▉      | 880/2226 [00:11<00:12, 107.14it/s]
# Extracting text embeddings:  40%|████      | 891/2226 [00:12<00:12, 104.77it/s]
# Extracting text embeddings:  41%|████      | 902/2226 [00:12<00:12, 105.24it/s]
# Extracting text embeddings:  41%|████      | 913/2226 [00:12<00:12, 101.95it/s]
# Extracting text embeddings:  42%|████▏     | 924/2226 [00:12<00:12, 104.10it/s]
# Extracting text embeddings:  42%|████▏     | 936/2226 [00:12<00:12, 105.87it/s]
# Extracting text embeddings:  43%|████▎     | 948/2226 [00:12<00:11, 107.46it/s]
# Extracting text embeddings:  43%|████▎     | 959/2226 [00:12<00:11, 107.06it/s]
# Extracting text embeddings:  44%|████▎     | 970/2226 [00:12<00:11, 104.93it/s]
# Extracting text embeddings:  44%|████▍     | 982/2226 [00:12<00:11, 106.67it/s]
# Extracting text embeddings:  45%|████▍     | 993/2226 [00:12<00:11, 106.16it/s]
# Extracting text embeddings:  45%|████▌     | 1004/2226 [00:13<00:11, 103.80it/s]
# Extracting text embeddings:  46%|████▌     | 1015/2226 [00:13<00:12, 100.44it/s]
# Extracting text embeddings:  46%|████▌     | 1026/2226 [00:13<00:11, 101.21it/s]
# Extracting text embeddings:  47%|████▋     | 1037/2226 [00:13<00:11, 103.25it/s]
# Extracting text embeddings:  47%|████▋     | 1049/2226 [00:13<00:11, 105.35it/s]
# Extracting text embeddings:  48%|████▊     | 1060/2226 [00:13<00:10, 106.25it/s]
# Extracting text embeddings:  48%|████▊     | 1071/2226 [00:13<00:10, 106.40it/s]
# Extracting text embeddings:  49%|████▊     | 1082/2226 [00:13<00:10, 106.35it/s]
# Extracting text embeddings:  49%|████▉     | 1093/2226 [00:13<00:12, 92.88it/s]
# Extracting text embeddings:  50%|████▉     | 1103/2226 [00:14<00:13, 86.27it/s]
# Extracting text embeddings:  50%|████▉     | 1112/2226 [00:14<00:13, 82.38it/s]
# Extracting text embeddings:  50%|█████     | 1121/2226 [00:14<00:13, 82.64it/s]
# Extracting text embeddings:  51%|█████     | 1130/2226 [00:14<00:13, 83.76it/s]
# Extracting text embeddings:  51%|█████     | 1139/2226 [00:14<00:12, 84.35it/s]
# Extracting text embeddings:  52%|█████▏    | 1148/2226 [00:14<00:12, 84.88it/s]
# Extracting text embeddings:  52%|█████▏    | 1157/2226 [00:14<00:12, 84.58it/s]
# Extracting text embeddings:  52%|█████▏    | 1167/2226 [00:14<00:12, 87.69it/s]
# Extracting text embeddings:  53%|█████▎    | 1177/2226 [00:14<00:11, 89.85it/s]
# Extracting text embeddings:  53%|█████▎    | 1187/2226 [00:15<00:11, 90.03it/s]
# Extracting text embeddings:  54%|█████▍    | 1197/2226 [00:15<00:11, 87.02it/s]
# Extracting text embeddings:  54%|█████▍    | 1206/2226 [00:15<00:12, 83.16it/s]
# Extracting text embeddings:  55%|█████▍    | 1215/2226 [00:15<00:12, 82.21it/s]
# Extracting text embeddings:  55%|█████▍    | 1224/2226 [00:15<00:12, 81.30it/s]
# Extracting text embeddings:  55%|█████▌    | 1233/2226 [00:15<00:12, 78.61it/s]
# Extracting text embeddings:  56%|█████▌    | 1241/2226 [00:15<00:12, 77.60it/s]
# Extracting text embeddings:  56%|█████▌    | 1249/2226 [00:15<00:12, 75.16it/s]
# Extracting text embeddings:  57%|█████▋    | 1258/2226 [00:16<00:12, 78.15it/s]
# Extracting text embeddings:  57%|█████▋    | 1269/2226 [00:16<00:11, 86.54it/s]
# Extracting text embeddings:  57%|█████▋    | 1278/2226 [00:16<00:11, 85.44it/s]
# Extracting text embeddings:  58%|█████▊    | 1289/2226 [00:16<00:10, 92.39it/s]
# Extracting text embeddings:  58%|█████▊    | 1301/2226 [00:16<00:09, 97.82it/s]
# Extracting text embeddings:  59%|█████▉    | 1312/2226 [00:16<00:09, 100.69it/s]
# Extracting text embeddings:  59%|█████▉    | 1323/2226 [00:16<00:08, 102.27it/s]
# Extracting text embeddings:  60%|█████▉    | 1334/2226 [00:16<00:08, 103.70it/s]
# Extracting text embeddings:  60%|██████    | 1345/2226 [00:16<00:08, 104.50it/s]
# Extracting text embeddings:  61%|██████    | 1356/2226 [00:16<00:08, 105.62it/s]
# Extracting text embeddings:  61%|██████▏   | 1367/2226 [00:17<00:08, 105.04it/s]
# Extracting text embeddings:  62%|██████▏   | 1378/2226 [00:17<00:08, 104.13it/s]
# Extracting text embeddings:  62%|██████▏   | 1389/2226 [00:17<00:08, 100.74it/s]
# Extracting text embeddings:  63%|██████▎   | 1400/2226 [00:17<00:08, 102.75it/s]
# Extracting text embeddings:  63%|██████▎   | 1411/2226 [00:17<00:07, 104.50it/s]
# Extracting text embeddings:  64%|██████▍   | 1423/2226 [00:17<00:07, 106.36it/s]
# Extracting text embeddings:  64%|██████▍   | 1434/2226 [00:17<00:07, 106.37it/s]
# Extracting text embeddings:  65%|██████▍   | 1445/2226 [00:17<00:07, 105.64it/s]
# Extracting text embeddings:  65%|██████▌   | 1456/2226 [00:17<00:07, 106.35it/s]
# Extracting text embeddings:  66%|██████▌   | 1467/2226 [00:18<00:07, 102.71it/s]
# Extracting text embeddings:  66%|██████▋   | 1478/2226 [00:18<00:07, 103.35it/s]
# Extracting text embeddings:  67%|██████▋   | 1489/2226 [00:18<00:07, 99.10it/s]
# Extracting text embeddings:  67%|██████▋   | 1500/2226 [00:18<00:07, 101.73it/s]
# Extracting text embeddings:  68%|██████▊   | 1511/2226 [00:18<00:06, 103.63it/s]
# Extracting text embeddings:  68%|██████▊   | 1522/2226 [00:18<00:06, 105.04it/s]
# Extracting text embeddings:  69%|██████▉   | 1533/2226 [00:18<00:06, 105.93it/s]
# Extracting text embeddings:  69%|██████▉   | 1544/2226 [00:18<00:06, 106.40it/s]
# Extracting text embeddings:  70%|██████▉   | 1555/2226 [00:18<00:06, 107.08it/s]
# Extracting text embeddings:  70%|███████   | 1566/2226 [00:18<00:06, 107.15it/s]
# Extracting text embeddings:  71%|███████   | 1577/2226 [00:19<00:06, 107.89it/s]
# Extracting text embeddings:  71%|███████▏  | 1588/2226 [00:19<00:06, 105.64it/s]
# Extracting text embeddings:  72%|███████▏  | 1599/2226 [00:19<00:06, 103.05it/s]
# Extracting text embeddings:  72%|███████▏  | 1610/2226 [00:19<00:05, 104.87it/s]
# Extracting text embeddings:  73%|███████▎  | 1621/2226 [00:19<00:05, 105.85it/s]
# Extracting text embeddings:  73%|███████▎  | 1632/2226 [00:19<00:05, 106.41it/s]
# Extracting text embeddings:  74%|███████▍  | 1643/2226 [00:19<00:05, 107.34it/s]
# Extracting text embeddings:  74%|███████▍  | 1654/2226 [00:19<00:05, 107.22it/s]
# Extracting text embeddings:  75%|███████▍  | 1665/2226 [00:19<00:05, 107.32it/s]
# Extracting text embeddings:  75%|███████▌  | 1676/2226 [00:19<00:05, 107.87it/s]
# Extracting text embeddings:  76%|███████▌  | 1687/2226 [00:20<00:05, 107.55it/s]
# Extracting text embeddings:  76%|███████▋  | 1698/2226 [00:20<00:05, 104.76it/s]
# Extracting text embeddings:  77%|███████▋  | 1709/2226 [00:20<00:04, 104.55it/s]
# Extracting text embeddings:  77%|███████▋  | 1720/2226 [00:20<00:04, 105.34it/s]
# Extracting text embeddings:  78%|███████▊  | 1731/2226 [00:20<00:04, 106.40it/s]
# Extracting text embeddings:  78%|███████▊  | 1742/2226 [00:20<00:04, 107.06it/s]
# Extracting text embeddings:  79%|███████▉  | 1753/2226 [00:20<00:04, 107.16it/s]
# Extracting text embeddings:  79%|███████▉  | 1764/2226 [00:20<00:04, 107.02it/s]
# Extracting text embeddings:  80%|███████▉  | 1775/2226 [00:20<00:04, 107.28it/s]
# Extracting text embeddings:  80%|████████  | 1786/2226 [00:21<00:04, 107.38it/s]
# Extracting text embeddings:  81%|████████  | 1797/2226 [00:21<00:04, 107.15it/s]
# Extracting text embeddings:  81%|████████  | 1808/2226 [00:21<00:04, 102.53it/s]
# Extracting text embeddings:  82%|████████▏ | 1819/2226 [00:21<00:04, 101.71it/s]
# Extracting text embeddings:  82%|████████▏ | 1830/2226 [00:21<00:03, 103.78it/s]
# Extracting text embeddings:  83%|████████▎ | 1841/2226 [00:21<00:03, 105.24it/s]
# Extracting text embeddings:  83%|████████▎ | 1852/2226 [00:21<00:03, 106.29it/s]
# Extracting text embeddings:  84%|████████▎ | 1863/2226 [00:21<00:03, 106.72it/s]
# Extracting text embeddings:  84%|████████▍ | 1874/2226 [00:21<00:03, 107.39it/s]
# Extracting text embeddings:  85%|████████▍ | 1885/2226 [00:21<00:03, 106.14it/s]
# Extracting text embeddings:  85%|████████▌ | 1896/2226 [00:22<00:03, 106.27it/s]
# Extracting text embeddings:  86%|████████▌ | 1907/2226 [00:22<00:03, 103.58it/s]
# Extracting text embeddings:  86%|████████▌ | 1918/2226 [00:22<00:02, 104.04it/s]
# Extracting text embeddings:  87%|████████▋ | 1929/2226 [00:22<00:02, 101.61it/s]
# Extracting text embeddings:  87%|████████▋ | 1940/2226 [00:22<00:02, 103.88it/s]
# Extracting text embeddings:  88%|████████▊ | 1951/2226 [00:22<00:02, 105.28it/s]
# Extracting text embeddings:  88%|████████▊ | 1962/2226 [00:22<00:02, 106.37it/s]
# Extracting text embeddings:  89%|████████▊ | 1973/2226 [00:22<00:02, 106.47it/s]
# Extracting text embeddings:  89%|████████▉ | 1984/2226 [00:22<00:02, 106.21it/s]
# Extracting text embeddings:  90%|████████▉ | 1995/2226 [00:23<00:02, 106.86it/s]
# Extracting text embeddings:  90%|█████████ | 2006/2226 [00:23<00:02, 103.74it/s]
# Extracting text embeddings:  91%|█████████ | 2017/2226 [00:23<00:02, 100.22it/s]
# Extracting text embeddings:  91%|█████████ | 2028/2226 [00:23<00:01, 100.27it/s]
# Extracting text embeddings:  92%|█████████▏| 2040/2226 [00:23<00:01, 103.43it/s]
# Extracting text embeddings:  92%|█████████▏| 2051/2226 [00:23<00:01, 104.94it/s]
# Extracting text embeddings:  93%|█████████▎| 2062/2226 [00:23<00:01, 105.43it/s]
# Extracting text embeddings:  93%|█████████▎| 2073/2226 [00:23<00:01, 105.44it/s]
# Extracting text embeddings:  94%|█████████▎| 2084/2226 [00:23<00:01, 106.19it/s]
# Extracting text embeddings:  94%|█████████▍| 2095/2226 [00:23<00:01, 105.87it/s]
# Extracting text embeddings:  95%|█████████▍| 2106/2226 [00:24<00:01, 106.58it/s]
# Extracting text embeddings:  95%|█████████▌| 2117/2226 [00:24<00:01, 103.79it/s]
# Extracting text embeddings:  96%|█████████▌| 2128/2226 [00:24<00:00, 105.33it/s]
# Extracting text embeddings:  96%|█████████▌| 2139/2226 [00:24<00:00, 103.61it/s]
# Extracting text embeddings:  97%|█████████▋| 2150/2226 [00:24<00:00, 104.70it/s]
# Extracting text embeddings:  97%|█████████▋| 2161/2226 [00:24<00:00, 105.33it/s]
# Extracting text embeddings:  98%|█████████▊| 2172/2226 [00:24<00:00, 105.97it/s]
# Extracting text embeddings:  98%|█████████▊| 2183/2226 [00:24<00:00, 106.64it/s]
# Extracting text embeddings:  99%|█████████▊| 2194/2226 [00:24<00:00, 107.29it/s]
# Extracting text embeddings:  99%|█████████▉| 2205/2226 [00:25<00:00, 106.02it/s]
# Extracting text embeddings: 100%|██████████| 2226/2226 [00:25<00:00, 88.24it/s]
# Extracting text embeddings: 100%|██████████| 200/200 [00:02<00:00, 90.00it/s]
# Extracting text embeddings: 100%|██████████| 2226/2226 [00:21<00:00, 102.75it/s]

# %%
# 5. Prepare Embeddings (CHANGED for Multi‐Label)
# -------------------------------------------------------
def prepare_text_embeddings(text_embeddings, df, label_cols=None, has_labels=True):
    """
    For each row in df, gather the text embedding and (optionally) the labels.
    label_cols: list of columns for multi-label (e.g. ["anger", "fear", "joy", ...])
    """
    combined_embeddings = []
    labels = []

    for idx, row in df.iterrows():
        if idx not in text_embeddings:
            continue
        # Get the [CLS] embedding
        text_embedding = text_embeddings[idx].squeeze()  # shape: (768,)
        combined_embeddings.append(text_embedding)

        if has_labels and label_cols is not None:
            # Collect all label columns as a float vector
            label_vector = row[label_cols].values.astype(float)  # shape: (5,)
            labels.append(label_vector)

    # Convert to Tensors
    if has_labels and label_cols is not None:
        X = torch.stack(combined_embeddings)
        Y = torch.tensor(labels, dtype=torch.float)  # multi-label => float
        return X, Y
    else:
        return torch.stack(combined_embeddings)

X_train, y_train = prepare_text_embeddings(train_text_embeddings, train_df, LABEL_COLS, has_labels=True)
X_val,   y_val   = prepare_text_embeddings(val_text_embeddings,   val_df,   LABEL_COLS, has_labels=True)
X_test           = prepare_text_embeddings(test_text_embeddings,  test_df,  LABEL_COLS, has_labels=False)

print("X_train:", X_train.shape, "y_train:", y_train.shape)
print("X_val:  ", X_val.shape,   "y_val:  ", y_val.shape)
print("X_test: ", X_test.shape)
# Out:
# X_train: torch.Size([2226, 768]) y_train: torch.Size([2226, 6])
# X_val:   torch.Size([200, 768]) y_val:   torch.Size([200, 6])
# X_test:  torch.Size([2226, 768])

# %%
def balance_multilabel_data(X, Y):
    """
    Oversample minority label-combinations in a multi-label setting.
    1. Convert each row's label vector (like [1,0,1,0,0]) into a tuple (1.0,0.0,1.0,0.0,0.0).
    2. Count how many rows share that exact tuple (i.e., label combination).
    3. Duplicate those rows until they match the frequency of the most common combination.

    NOTE: This lumps each distinct 5-label pattern as one "class."
    If every row has a unique pattern, this won't help much.
    """
    from collections import Counter

    # Convert each label row to a tuple
    label_tuples = [tuple(row.tolist()) for row in Y]
    class_counts = Counter(label_tuples)
    max_count = max(class_counts.values())

    # We'll store duplicates in lists, then convert to tensors
    balanced_embeddings = []
    balanced_labels = []

    for i, label_tuple in enumerate(label_tuples):
        balanced_embeddings.append(X[i])
        balanced_labels.append(label_tuple)

        current_count = class_counts[label_tuple]
        # e.g., duplicates_needed = how many times to replicate?
        duplicates_needed = int((max_count - current_count) / current_count)

        for _ in range(duplicates_needed):
            balanced_embeddings.append(X[i])
            balanced_labels.append(label_tuple)

    balanced_embeddings = torch.stack(balanced_embeddings)
    balanced_labels = torch.tensor(balanced_labels, dtype=torch.float)
    print(f"Original dataset size: {X.shape[0]}")
    print(f"Balanced dataset size: {balanced_embeddings.shape[0]}")
    return balanced_embeddings, balanced_labels

# Call our new multi-label balancing function
X_train, y_train = balance_multilabel_data(X_train, y_train)
# Out:
# Original dataset size: 2226
# Balanced dataset size: 19649

# %%
# 6. Define Multi‐Label MLP Model (CHANGED)
# -------------------------------------------------------
class MLPModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout_p=0.5):
        super(MLPModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim[0])
        self.relu = nn.ReLU()
        self.dropout1 = nn.Dropout(p=dropout_p)
        self.fc2 = nn.Linear(hidden_dim[0], hidden_dim[1])
        self.dropout2 = nn.Dropout(p=dropout_p)
        self.fc3 = nn.Linear(hidden_dim[1], output_dim)
        # For multi‐label, we *do not* apply softmax, we will use BCEWithLogitsLoss

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.dropout1(x)
        x = self.relu(self.fc2(x))
        x = self.dropout2(x)
        x = self.fc3(x)            # shape: (batch_size, 5)
        # No softmax here for multi‐label. Return raw logits for BCEWithLogitsLoss
        return x

# %%
# Model & Hyperparams
input_dim    = X_train.shape[1]        # e.g. 768
hidden_dim   = [786, 512]             # can be tuned
output_dim   = len(LABEL_COLS)        # 5 for multi‐label
dropout_p    = 0.3
num_epochs   = 5
batch_size   = 16
learning_rate = 1e-4

model = MLPModel(input_dim, hidden_dim, output_dim, dropout_p).to(device)

# %%
# 7. CHANGED: Use BCEWithLogitsLoss (for multi‐label)
# -------------------------------------------------------
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# 8. Dataloaders
# -------------------------------------------------------
train_dataset = TensorDataset(X_train, y_train)
val_dataset   = TensorDataset(X_val,   y_val)
test_dataset  = TensorDataset(X_test)  # no labels for test

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size)
test_loader  = DataLoader(test_dataset,  batch_size=batch_size)

# %%
# 9. Metrics for Multi‐Label (CHANGED)
# -------------------------------------------------------
def calculate_metrics(preds, labels):
    """
    preds, labels are lists (or arrays) of shape (N, 5).
    We'll do an example with macro avg for PRF.
    """
    preds = np.array(preds)
    labels = np.array(labels)

    # Example: For each label, threshold at 0.5
    # (We already do that during loop, but let's be explicit.)
    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, preds, average='macro', zero_division=0
    )
    # Multi‐label “accuracy” can be ambiguous.
    # Some do “exact match ratio”, etc. We'll do a simple overall average:
    accuracy = (preds == labels).mean()

    return accuracy, precision, recall, f1

# %%
# 10. Train and Validate (CHANGES in Predictions)
# -------------------------------------------------------
def train_and_save_best_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, save_dir):
    best_f1 = -float('inf')
    best_model_path = None

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        all_train_preds, all_train_labels = [], []

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)  # shape: (batch_size, 5)
            # For BCEWithLogitsLoss, labels should be float
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            # Convert logits -> probabilities -> binary predictions
            preds = (torch.sigmoid(outputs) > 0.5).float()
            all_train_preds.extend(preds.cpu().tolist())
            all_train_labels.extend(labels.cpu().tolist())

        # Training metrics
        train_accuracy, train_precision, train_recall, train_f1 = calculate_metrics(all_train_preds, all_train_labels)

        # Validation
        model.eval()
        val_loss = 0
        all_val_preds, all_val_labels = [], []
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)  # shape: (batch_size, 5)

                loss = criterion(outputs, labels)
                val_loss += loss.item()

                preds = (torch.sigmoid(outputs) > 0.5).float()
                all_val_preds.extend(preds.cpu().tolist())
                all_val_labels.extend(labels.cpu().tolist())

        val_accuracy, val_precision, val_recall, val_f1 = calculate_metrics(all_val_preds, all_val_labels)

        print(
            f"Epoch {epoch+1}/{num_epochs} "
            f"Train Loss: {train_loss/len(train_loader):.4f}, "
            f"Train Acc: {train_accuracy:.4f}, F1: {train_f1:.4f} | "
            f"Val Loss: {val_loss/len(val_loader):.4f}, "
            f"Val Acc: {val_accuracy:.4f}, F1: {val_f1:.4f}"
        )

        # Save best model by val_f1
        if val_f1 > best_f1:
            best_f1 = val_f1
            best_model_path = os.path.join(save_dir, f"best_model_epoch_{epoch+1}_f1_{val_f1:.4f}.pth")
            torch.save(model.state_dict(), best_model_path)
            print(f"Best model saved with F1: {val_f1:.4f} at epoch {epoch+1}")

    return best_model_path

save_dir = "./models"
os.makedirs(save_dir, exist_ok=True)

best_model_path = train_and_save_best_model(
    model, train_loader, val_loader, criterion, optimizer, num_epochs, save_dir
)

print(f"Best model saved at: {best_model_path}")
# Out:
# Epoch 1/50 Train Loss: 0.3606, Train Acc: 0.8392, F1: 0.7411 | Val Loss: 0.5504, Val Acc: 0.7525, F1: 0.2431
# Best model saved with F1: 0.2431 at epoch 1
# Epoch 2/50 Train Loss: 0.1932, Train Acc: 0.9249, F1: 0.8939 | Val Loss: 0.5242, Val Acc: 0.7667, F1: 0.2684
# Best model saved with F1: 0.2684 at epoch 2
# Epoch 3/50 Train Loss: 0.1345, Train Acc: 0.9505, F1: 0.9312 | Val Loss: 0.5339, Val Acc: 0.7775, F1: 0.2643
# Epoch 4/50 Train Loss: 0.1006, Train Acc: 0.9649, F1: 0.9519 | Val Loss: 0.5361, Val Acc: 0.7817, F1: 0.2458
# Epoch 5/50 Train Loss: 0.0782, Train Acc: 0.9733, F1: 0.9638 | Val Loss: 0.5491, Val Acc: 0.8050, F1: 0.2836
# Best model saved with F1: 0.2836 at epoch 5
# Epoch 6/50 Train Loss: 0.0630, Train Acc: 0.9793, F1: 0.9718 | Val Loss: 0.5761, Val Acc: 0.7958, F1: 0.2689
# Epoch 7/50 Train Loss: 0.0532, Train Acc: 0.9824, F1: 0.9761 | Val Loss: 0.5945, Val Acc: 0.8000, F1: 0.2544
# Epoch 8/50 Train Loss: 0.0459, Train Acc: 0.9847, F1: 0.9792 | Val Loss: 0.6056, Val Acc: 0.8008, F1: 0.2611
# Epoch 9/50 Train Loss: 0.0395, Train Acc: 0.9867, F1: 0.9818 | Val Loss: 0.6233, Val Acc: 0.8067, F1: 0.2637
# Epoch 10/50 Train Loss: 0.0354, Train Acc: 0.9881, F1: 0.9837 | Val Loss: 0.6555, Val Acc: 0.8025, F1: 0.2584
# Epoch 11/50 Train Loss: 0.0298, Train Acc: 0.9900, F1: 0.9860 | Val Loss: 0.6597, Val Acc: 0.8217, F1: 0.2739
# Epoch 12/50 Train Loss: 0.0283, Train Acc: 0.9904, F1: 0.9867 | Val Loss: 0.7395, Val Acc: 0.8117, F1: 0.2303
# Epoch 13/50 Train Loss: 0.0258, Train Acc: 0.9913, F1: 0.9882 | Val Loss: 0.7021, Val Acc: 0.8092, F1: 0.2498
# Epoch 14/50 Train Loss: 0.0227, Train Acc: 0.9924, F1: 0.9895 | Val Loss: 0.7086, Val Acc: 0.8158, F1: 0.2655
# Epoch 15/50 Train Loss: 0.0202, Train Acc: 0.9932, F1: 0.9907 | Val Loss: 0.7307, Val Acc: 0.8175, F1: 0.2637
# Epoch 16/50 Train Loss: 0.0197, Train Acc: 0.9934, F1: 0.9909 | Val Loss: 0.7277, Val Acc: 0.8142, F1: 0.2697
# Epoch 17/50 Train Loss: 0.0175, Train Acc: 0.9939, F1: 0.9916 | Val Loss: 0.8150, Val Acc: 0.8050, F1: 0.2425
# Epoch 18/50 Train Loss: 0.0158, Train Acc: 0.9946, F1: 0.9926 | Val Loss: 0.7600, Val Acc: 0.8175, F1: 0.2461
# Epoch 19/50 Train Loss: 0.0154, Train Acc: 0.9949, F1: 0.9928 | Val Loss: 0.8648, Val Acc: 0.8200, F1: 0.2593
# Epoch 20/50 Train Loss: 0.0147, Train Acc: 0.9949, F1: 0.9930 | Val Loss: 0.8537, Val Acc: 0.8208, F1: 0.2949
# Best model saved with F1: 0.2949 at epoch 20
# Epoch 21/50 Train Loss: 0.0132, Train Acc: 0.9954, F1: 0.9937 | Val Loss: 0.8527, Val Acc: 0.8283, F1: 0.2905
# Epoch 22/50 Train Loss: 0.0123, Train Acc: 0.9958, F1: 0.9942 | Val Loss: 0.9007, Val Acc: 0.8058, F1: 0.2313
# Epoch 23/50 Train Loss: 0.0117, Train Acc: 0.9959, F1: 0.9945 | Val Loss: 0.9448, Val Acc: 0.8142, F1: 0.2446
# Epoch 24/50 Train Loss: 0.0109, Train Acc: 0.9963, F1: 0.9949 | Val Loss: 0.9021, Val Acc: 0.8200, F1: 0.2918
# Epoch 25/50 Train Loss: 0.0108, Train Acc: 0.9963, F1: 0.9949 | Val Loss: 0.9461, Val Acc: 0.8117, F1: 0.2606
# Epoch 26/50 Train Loss: 0.0099, Train Acc: 0.9964, F1: 0.9950 | Val Loss: 0.9496, Val Acc: 0.8225, F1: 0.2585
# Epoch 27/50 Train Loss: 0.0092, Train Acc: 0.9968, F1: 0.9957 | Val Loss: 0.9844, Val Acc: 0.8058, F1: 0.2549
# Epoch 28/50 Train Loss: 0.0097, Train Acc: 0.9967, F1: 0.9954 | Val Loss: 0.9902, Val Acc: 0.8133, F1: 0.2671
# Epoch 29/50 Train Loss: 0.0092, Train Acc: 0.9968, F1: 0.9956 | Val Loss: 1.0026, Val Acc: 0.8142, F1: 0.2655
# Epoch 30/50 Train Loss: 0.0094, Train Acc: 0.9968, F1: 0.9955 | Val Loss: 1.0049, Val Acc: 0.8300, F1: 0.2808
# Epoch 31/50 Train Loss: 0.0082, Train Acc: 0.9970, F1: 0.9959 | Val Loss: 1.0239, Val Acc: 0.8308, F1: 0.2820
# Epoch 32/50 Train Loss: 0.0081, Train Acc: 0.9973, F1: 0.9963 | Val Loss: 1.0571, Val Acc: 0.8200, F1: 0.2844
# Epoch 33/50 Train Loss: 0.0074, Train Acc: 0.9975, F1: 0.9965 | Val Loss: 1.0789, Val Acc: 0.8200, F1: 0.2467
# Epoch 34/50 Train Loss: 0.0074, Train Acc: 0.9974, F1: 0.9965 | Val Loss: 1.0280, Val Acc: 0.8150, F1: 0.2661
# Epoch 35/50 Train Loss: 0.0075, Train Acc: 0.9974, F1: 0.9964 | Val Loss: 1.1147, Val Acc: 0.8242, F1: 0.2614
# Epoch 36/50 Train Loss: 0.0063, Train Acc: 0.9979, F1: 0.9970 | Val Loss: 1.1503, Val Acc: 0.8167, F1: 0.2640
# Epoch 37/50 Train Loss: 0.0065, Train Acc: 0.9977, F1: 0.9967 | Val Loss: 1.1031, Val Acc: 0.8267, F1: 0.2810
# Epoch 38/50 Train Loss: 0.0074, Train Acc: 0.9974, F1: 0.9964 | Val Loss: 1.1477, Val Acc: 0.8208, F1: 0.2126
# Epoch 39/50 Train Loss: 0.0067, Train Acc: 0.9977, F1: 0.9969 | Val Loss: 1.1411, Val Acc: 0.8200, F1: 0.2260
# Epoch 40/50 Train Loss: 0.0062, Train Acc: 0.9978, F1: 0.9970 | Val Loss: 1.1177, Val Acc: 0.8158, F1: 0.2323
# Epoch 41/50 Train Loss: 0.0057, Train Acc: 0.9981, F1: 0.9974 | Val Loss: 1.1446, Val Acc: 0.8242, F1: 0.2422
# Epoch 42/50 Train Loss: 0.0054, Train Acc: 0.9982, F1: 0.9975 | Val Loss: 1.2549, Val Acc: 0.8333, F1: 0.2794
# Epoch 43/50 Train Loss: 0.0061, Train Acc: 0.9979, F1: 0.9972 | Val Loss: 1.2493, Val Acc: 0.8158, F1: 0.2776
# Epoch 44/50 Train Loss: 0.0057, Train Acc: 0.9981, F1: 0.9973 | Val Loss: 1.2379, Val Acc: 0.8117, F1: 0.2788
# Epoch 45/50 Train Loss: 0.0053, Train Acc: 0.9981, F1: 0.9974 | Val Loss: 1.1744, Val Acc: 0.8300, F1: 0.2744
# Epoch 46/50 Train Loss: 0.0054, Train Acc: 0.9981, F1: 0.9973 | Val Loss: 1.2939, Val Acc: 0.8183, F1: 0.2000
# Epoch 47/50 Train Loss: 0.0055, Train Acc: 0.9981, F1: 0.9973 | Val Loss: 1.2974, Val Acc: 0.8192, F1: 0.2497
# Epoch 48/50 Train Loss: 0.0066, Train Acc: 0.9978, F1: 0.9971 | Val Loss: 1.2412, Val Acc: 0.8317, F1: 0.2858
# Epoch 49/50 Train Loss: 0.0050, Train Acc: 0.9983, F1: 0.9976 | Val Loss: 1.3445, Val Acc: 0.8200, F1: 0.3058
# Best model saved with F1: 0.3058 at epoch 49
# Epoch 50/50 Train Loss: 0.0056, Train Acc: 0.9980, F1: 0.9972 | Val Loss: 1.2570, Val Acc: 0.8208, F1: 0.2487
# Best model saved at: ./models/best_model_epoch_49_f1_0.3058.pth

# %%
# 11. Test Predictions (CHANGES for Multi‐Label)
# -------------------------------------------------------
def predict_and_generate_submission(test_loader, best_model_path, submission_file_path):
    # Reload a fresh model
    inference_model = MLPModel(input_dim, hidden_dim, output_dim, dropout_p).to(device)
    inference_model.load_state_dict(torch.load(best_model_path))
    inference_model.eval()

    # We'll store multi‐label predictions as 0/1 for each label
    test_predictions = []
    with torch.no_grad():
        for (inputs,) in test_loader:  # Each batch is a tuple containing only X
            inputs = inputs.to(device)
            outputs = inference_model(inputs)
            preds = (torch.sigmoid(outputs) > 0.5).int()  # shape: (batch_size, 5)
            test_predictions.append(preds.cpu())

    test_predictions = torch.cat(test_predictions, dim=0).numpy()  # shape: (num_samples, 5)

    # Build submission DataFrame
    submission_df = pd.DataFrame({
        "id": test_df["id"],  # or whatever your ID is
        "anger_pred":    test_predictions[:, 0],
        "disgust_pred":  test_predictions[:, 1],
        "fear_pred":     test_predictions[:, 2],
        "joy_pred":      test_predictions[:, 3],
        "sadness_pred": test_predictions[:, 4],
        "surprise_pred":test_predictions[:, 5]
    })

    submission_df.to_csv(submission_file_path, index=False)
    print(f"Submission file saved to {submission_file_path}")
    return submission_df

submission_file_path = "submission.csv"
submission_df = predict_and_generate_submission(test_loader, best_model_path, submission_file_path)
submission_df.head()
# Out:
# Submission file saved to submission.csv
#                         id  anger_pred  disgust_pred  fear_pred  joy_pred  \
# 0  ptbr_test_track_a_00001           0             0          0         0
# 1  ptbr_test_track_a_00002           0             0          0         1
# 2  ptbr_test_track_a_00003           0             0          0         1
# 3  ptbr_test_track_a_00004           0             0          0         0
# 4  ptbr_test_track_a_00005           0             0          0         1
#
#    sadness_pred  surprise_pred
# 0             1              0
# 1             0              0
# 2             1              0
# 3             0              0
# 4             0              0

# %%
from sklearn.metrics import confusion_matrix  # Add this to your existing sklearn imports

def plot_all_confusion_matrices(model, data_loader, label_cols, save_path=None):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            preds = (torch.sigmoid(outputs) > 0.5).float()  # Get binary predictions
            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())

    all_preds = torch.cat(all_preds, dim=0).numpy()
    all_labels = torch.cat(all_labels, dim=0).numpy()

    num_labels = len(label_cols)
    fig, axes = plt.subplots(2, 3, figsize=(18, 12))  # 2x3 grid for 5 labels + 1 empty
    axes = axes.ravel()

    for i in range(num_labels):
        cm = confusion_matrix(all_labels[:, i], all_preds[:, i])
        ax = axes[i]
        sns.heatmap(
            cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["No", "Yes"], yticklabels=["No", "Yes"], ax=ax,
            annot_kws={"size": 14}
        )
        ax.set_xlabel("Predicted", fontsize=12)
        ax.set_ylabel("Actual", fontsize=12)
        ax.set_title(f"{label_cols[i]}", fontsize=14)
        ax.tick_params(axis='both', labelsize=10)

    # Hide the empty subplot
    if num_labels < len(axes):
        for j in range(num_labels, len(axes)):
            fig.delaxes(axes[j])

    if save_path:
        plt.savefig(save_path, bbox_inches='tight', dpi=300)
        print(f"Confusion matrices saved to: {save_path}")


    plt.tight_layout()
    plt.show()

# Call the function after training
plot_all_confusion_matrices(model, val_loader, LABEL_COLS,save_path="/content/confusion_matrices.png")
# Out:
# Confusion matrices saved to: /content/confusion_matrices.png

# %%
def display_predictions(model, data_loader, df, num_samples=5):
    model.eval()
    all_preds, all_labels, texts = [], [], []

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            #batch_size = outputs.size(0) #Unnecessary
            #outputs = outputs.view(batch_size, 6, 4) # Remove this line
            preds = (torch.sigmoid(outputs) > 0.5).int() #Get Multi-label predictions

            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())

    all_preds = torch.cat(all_preds, dim=0).numpy()
    all_labels = torch.cat(all_labels, dim=0).numpy()

    # Add corresponding text data for reference
    texts = df[TEXT_VAR].tolist()

    correct_samples = []
    incorrect_samples = []

    for i in range(len(all_preds)):
        if np.array_equal(all_preds[i], all_labels[i]):  # Fully correct
            correct_samples.append((texts[i], all_preds[i], all_labels[i]))
        else:  # Incorrect prediction
            incorrect_samples.append((texts[i], all_preds[i], all_labels[i]))

    print("\n✅ Correct Predictions:")
    for i, (text, pred, true) in enumerate(correct_samples[:num_samples]):
        print(f"\n🔹 Sample {i+1}:")
        print(f"Text: {text}")
        print(f"Predicted: {pred} | Actual: {true}")

    print("\n❌ Incorrect Predictions:")
    for i, (text, pred, true) in enumerate(incorrect_samples[:num_samples]):
        print(f"\n🔹 Sample {i+1}:")
        print(f"Text: {text}")
        print(f"Predicted: {pred} | Actual: {true}")

# Call the function
display_predictions(model, val_loader, val_df, num_samples=5)
# Out:
# ✅ Correct Predictions:
#
# 🔹 Sample 1:
# Text: Eu n sou o com quem vc conversava, só fui mostrar q o STF tá s mandando investigar todos os lados, mas já q agora vc tá conversando com três users sobre o mesmo assunto, saiba q eu apoio s e agora vc apoia também já q vc disse "só concordo se você apoiar que o STF mande investigar e prender anti-sistema de todos os lados", então agora vc pode dizer q acha o Bolsonaro antidemocracia.
# Predicted: [1 0 0 0 0 0] | Actual: [1. 0. 0. 0. 0. 0.]
#
# 🔹 Sample 2:
# Text: essa aqui q vou fazer
# Predicted: [0 0 0 0 0 0] | Actual: [0. 0. 0. 0. 0. 0.]
#
# 🔹 Sample 3:
# Text: pedro eh perfeito msm
# Predicted: [0 0 0 1 0 0] | Actual: [0. 0. 0. 1. 0. 0.]
#
# 🔹 Sample 4:
# Text: Eu li direito?! SUSPEITOS!? Mas todos, segundo a constituição, não são INOCENTES até prova ao contrário? Vou ai perguntar a algum jurista...
# Predicted: [1 0 0 0 0 1] | Actual: [1. 0. 0. 0. 0. 1.]
#
# 🔹 Sample 5:
# Text: Já to me preparando porque sei que vou falir Eu chegando no local no dia cheio de dívidas mas mandando tudo pra puta que pariu
# Predicted: [1 0 0 0 0 0] | Actual: [1. 0. 0. 0. 0. 0.]
#
# ❌ Incorrect Predictions:
#
# 🔹 Sample 1:
# Text: sei nem qual é mais feio ???????
# Predicted: [1 0 0 0 0 1] | Actual: [0. 0. 0. 0. 0. 1.]
#
# 🔹 Sample 2:
# Text: Eu entendi bem? Um pastor pede pra outro pastor levantar um grupo de pessoas e espancar ele no Twitter???? Q tipo de Deus esses caras seguem?? Q tipo de religião eles pregam???
# Predicted: [1 0 0 0 0 0] | Actual: [1. 1. 0. 0. 0. 1.]
#
# 🔹 Sample 3:
# Text: tá muito linda pqp
# Predicted: [0 0 0 1 0 0] | Actual: [0. 0. 0. 1. 0. 1.]
#
# 🔹 Sample 4:
# Text: não gosto de gente que fica em cima do muro, gosta de indecisão vai atrás de um (a) libriano (a)
# Predicted: [0 0 0 0 0 0] | Actual: [1. 0. 0. 0. 0. 0.]
#
# 🔹 Sample 5:
# Text: Zero maturidade aqui. Meldels
# Predicted: [0 0 0 1 0 0] | Actual: [1. 1. 0. 0. 0. 0.]
